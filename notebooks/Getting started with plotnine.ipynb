# %%
# !pip install pandas 
# !pip install plotnine

# %%
import pandas as pd
df = pd.DataFrame({"gene": ["TP53", "MDM2"], "length":[50, 100], "TPM": [10**6 - 10, 10]});
df
# Out:
#    gene  length     TPM
# 0  TP53      50  999990
# 1  MDM2     100      10

# %%
import plotnine as pn
from plotnine import (ggplot, aes, geom_point)

# %%
(
    ggplot(df, aes(x="gene", y="TPM")) + 
    geom_point()
)

# %%
# see names of variables are defined in the namespace
# %who
# Out:
# aes	 df	 geom_point	 ggplot	 pd	 pn

# %%
# see details of variables are defined in the namespace

# %whos
# Out:
# Variable     Type         Data/Info
# -----------------------------------
# aes          type         <class 'plotnine.mapping.aes.aes'>
# df           DataFrame       gene  length     TPM\n<...>\n1  MDM2     100      10
# geom_point   Register     <class 'plotnine.geoms.geom_point.geom_point'>
# ggplot       type         <class 'plotnine.ggplot.ggplot'>
# pd           module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# pn           module       <module 'plotnine' from '<...>es/plotnine/__init__.py'>

# %%
# get documentation 
ggplot?

# %%
# get the source
ggplot??

# %%
# shell commands mostly work if you start with "!"
# !ls
# Out:
# Getting started with plotnine.ipynb

# %%
# !ls -alh
# Out:
# total 88
# drwxr-xr-x  4 iskander  staff   128B Jun 25 12:02 .
# drwxr-xr-x  8 iskander  staff   256B Jun 25 11:53 ..
# drwxr-xr-x  3 iskander  staff    96B Jun 25 11:54 .ipynb_checkpoints
# -rw-r--r--  1 iskander  staff    43K Jun 25 12:02 Getting started with plotnine.ipynb

# %%
# nothing changed?
# !git diff

# %%
# let's add this file to the git repo
# !git add *.ipynb

# %%
# !git stat
